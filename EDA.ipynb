# %%
# External dependencies: numpy, pandas, matplotlib, seaborn, scikit-learn
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# Internal dependencies: re, sys, os
import re
import sys
import os

# %%
df = pd.read_csv("C:/Users/12678/OneDriveDrexelUniversity/Documents/Computer Vision Engineer/Case_Competitions/PhillyCodeFest/dsProject/recidivism_cleaned.csv")

# %%
# Out:
#        Unnamed: 0  Year Released  Year Reviewed   Race           Age  \
# 0               0           2010           2013  White      Under 25
# 1               1           2010           2013  White  55 and Older
# 2               2           2010           2013  White         25-34
# 3               3           2010           2013  White  55 and Older
# 4               4           2010           2013  Black         25-34
# ...           ...            ...            ...    ...           ...
# 16410       26009           2015           2018  White         25-34
# 16411       26011           2015           2018  White         45-54
# 16412       26016           2015           2018  White         25-34
# 16413       26017           2015           2018  Black      Under 25
# 16414       26018           2015           2018  White      Under 25
#
#                        Degree       Offense     SubOffense District  \
# 0                    D Felony       Violent        Assault      4JD
# ...
